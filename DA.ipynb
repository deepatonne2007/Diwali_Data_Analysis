# %% [markdown]
# #### Data Aanalysis for Diwali sales data (clickget)
#
# ### Steps in DA
#
# > objective - draw meaningfull insights and values information for forecasting (future prediction)and decison making for business growth
#
# > Data collection - tabular format(rows,cols) - pandas
#
# > Data cleaning
#
# >EDA (Explotary Data Analysis)
#
# > Visulization (charts) and key information
#
# > Conclusion : Report

# %%
! pip install numpy pandas

# %%
# import libraries or modules

import numpy as np
import pandas as pd

# %%
df =pd.read_csv(r"C:\Users\klemp\Desktop\deepa\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv",encoding= 'unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %%
len(df)
# Out:
# 11251

# %%
df.drop([])
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
len(df)
# Out:
# 11251

# %%
df.drop_duplicates(inplace=True)

# %%
len(df) # 11251 -8 =11243
# Out:
# 11243

# %% [markdown]
# ### Done with duplicate rows

# %%
df.nunique()
# Out:
# User_ID             3755
# Cust_name           1250
# Product_ID          2351
# Gender                 2
# Age Group              7
# Age                   81
# Marital_Status         2
# State                 16
# Zone                   5
# Occupation            15
# Product_Category      18
# Orders                 4
# Amount              6584
# Status                 0
# unnamed1               0
# dtype: int64

# %%
#nchecking the states where we sell our products

df['State'].value_counts()
# Out:
# State
# Uttar Pradesh       1944
# Maharashtra         1523
# Karnataka           1305
# Delhi               1107
# Madhya Pradesh       923
# Andhra Pradesh       812
# Himachal Pradesh     608
# Kerala               453
# Haryana              451
# Bihar                433
# Gujarat              428
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df['Cust_name'].str.strip([0-9])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 11246   NaN
# 11247   NaN
# 11248   NaN
# 11249   NaN
# 11250   NaN
# Name: Cust_name, Length: 11243, dtype: float64

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11243
# unnamed1            11243
# dtype: int64

# %%
#view null rows  for amount cell
f1 = df['Amount'].isna()
df[f1]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
f2=df['Product_Category']=="Auto"
df[f2]
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0     1002903  Sanskriti  P00125942      F     26-35   28               0
# 1     1000732     Kartik  P00110942      F     26-35   35               1
# 2     1001990      Bindu  P00118542      F     26-35   35               1
# 3     1001425     Sudevi  P00237842      M      0-17   16               0
# 4     1000588       Joni  P00057942      M     26-35   28               1
# ...       ...        ...        ...    ...       ...  ...             ...
# 2460  1001941      Gopal  P00259142      M     36-45   26               1
# 2461  1001202    Diwakar  P00277642      F     36-45   39               0
# 4588  1005642     Eplett  P00057542      F      0-17   13               0
# 4651  1004704    Manshul  P00085242      F     18-25   24               1
# 4687  1000157   Michelle  P00102042      F     36-45   41               1
#
#                State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.drop(columns=['Status','unnamed1'],inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# * Done with unwanted cols and rows which has any null values

# %% [markdown]
# #### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11231 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  object
#  2   Product_ID        11231 non-null  object
#  3   Gender            11231 non-null  object
#  4   Age Group         11231 non-null  object
#  5   Age               11231 non-null  int64
#  6   Marital_Status    11231 non-null  int64
#  7   State             11231 non-null  object
#  8   Zone              11231 non-null  object
#  9   Occupation        11231 non-null  object
#  10  Product_Category  11231 non-null  object
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
# typecasting of columns 
#amount = float -int 
df['Amount'] = df['Amount'].astype('int32') #16 bits =2 byte

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11231 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  object
#  2   Product_ID        11231 non-null  object
#  3   Gender            11231 non-null  object
#  4   Age Group         11231 non-null  object
#  5   Age               11231 non-null  int64
#  6   Marital_Status    11231 non-null  int64
#  7   State             11231 non-null  object
#  8   Zone              11231 non-null  object
#  9   Occupation        11231 non-null  object
#  10  Product_Category  11231 non-null  object
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
# to view  the statical information
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123100e+04  11231.000000    11231.000000  11231.000000  11231.000000
# mean   1.003004e+06     35.411985        0.419998      2.489093   9454.084676
# std    1.716055e+03     12.756116        0.493580      1.114880   5221.728074
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004428e+06     43.000000        1.000000      3.000000  12677.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# to view  the statical information
df.describe()[['Age',	'Marital_Status',	'Orders',	'Amount']]
# Out:
#                 Age  Marital_Status        Orders        Amount
# count  11231.000000    11231.000000  11231.000000  11231.000000
# mean      35.411985        0.419998      2.489093   9454.084676
# std       12.756116        0.493580      1.114880   5221.728074
# min       12.000000        0.000000      1.000000    188.000000
# 25%       27.000000        0.000000      2.000000   5443.000000
# 50%       33.000000        0.000000      2.000000   8109.000000
# 75%       43.000000        1.000000      3.000000  12677.500000
# max       92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# Find out number of male and famale

# %%
 df['Gender'].value_counts()
# Out:
# Gender
# F    7828
# M    3403
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as  sns

# %% [markdown]
# Gender

# %%
ax = sns.countplot(x= 'Gender',data = df) # bar chart for catgories with  quantity 
for  bar in ax.containers:
    ax.bar_label(bar)

# %%
d=df['Gender'].value_counts()
d
# Out:
# Gender
# F    7828
# M    3403
# Name: count, dtype: int64

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d.index
# Out:
# Index(['F', 'M'], dtype='object', name='Gender')

# %% [markdown]
# >  Female are  buying more then male

# %% [markdown]
# ### who are spending more (male/female)

# %%
df['Amount']
# Out:
# 0        23952
# 1        23934
# 2        23924
# 3        23912
# 4        23877
#          ...
# 11246      370
# 11247      367
# 11248      213
# 11249      206
# 11250      188
# Name: Amount, Length: 11231, dtype: int32

# %% [markdown]
# ### Grouping

# %%
df.groupby(['Gender'])

# %%
df.groupby(['Gender'])['Amount']

# %%
df.groupby(['Gender'])['Amount'].sum()
# Out:
# Gender
# F    74307679
# M    31871146
# Name: Amount, dtype: int32

# %%
df.groupby(['Gender'])['Amount'].count()
# Out:
# Gender
# F    7828
# M    3403
# Name: Amount, dtype: int64

# %%
df.groupby(['Gender'])['Amount'].sum().sort_values()
# Out:
# Gender
# M    31871146
# F    74307679
# Name: Amount, dtype: int32

# %%
sales_gen  = df.groupby(['Gender'])['Amount'].sum().sort_values()

# %%
sales_df=pd.DataFrame(sales_gen)

# %%
type(sales_gen)
# Out:
# pandas.core.frame.DataFrame

# %%
ax=sns.barplot(x='Gender',y='Amount',data =sales_df)

# %%
ax=sns.barplot(x='Gender',y='Amount',data =sales_df)
for  bar in ax.containers:
    ax.bar_label(bar)

# %%
for i in list(ax.containers[0]):
    print(i)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=3.18711e+07, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=7.43077e+07, angle=0)

# %%
74307679-31871146
# Out:
# 42436533

# %% [markdown]
# > Female are spending more than male(with the difference of 42436533)

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Insights From Age(col)

# %%
df['Age'].value_counts()
# Out:
# Age
# 30    522
# 26    494
# 28    458
# 29    454
# 31    447
#      ...
# 82      8
# 70      7
# 92      7
# 59      7
# 62      5
# Name: count, Length: 81, dtype: int64

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %%
df['Age Group'].value_counts()
# Out:
# Age Group
# 26-35    4536
# 36-45    2282
# 18-25    1878
# 46-50     983
# 51-55     829
# 55+       427
# 0-17      296
# Name: count, dtype: int64

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Age Group'])

# %%
df.groupby(['Age Group'])['Amount']

# %%
df.groupby(['Age Group'])['Amount'].sum()
# Out:
# Age Group
# 0-17      2699653
# 18-25    17235530
# 26-35    42581767
# 36-45    22135135
# 46-50     9207844
# 51-55     8237909
# 55+       4080987
# Name: Amount, dtype: int32

# %%
df.groupby(['Age Group'])['Amount'].sum().sort_values()
# Out:
# Age Group
# 0-17      2699653
# 55+       4080987
# 51-55     8237909
# 46-50     9207844
# 18-25    17235530
# 36-45    22135135
# 26-35    42581767
# Name: Amount, dtype: int32

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

ax=sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

ax=sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
df.groupby(['State'],as_index=False)['Orders'].sum()
# Out:
#                State  Orders
# 0     Andhra Pradesh    2051
# 1              Bihar    1058
# 2              Delhi    2740
# 3            Gujarat    1063
# 4            Haryana    1106
# 5   Himachal Pradesh    1568
# 6          Jharkhand     953
# 7          Karnataka    3240
# 8             Kerala    1137
# 9     Madhya Pradesh    2252
# 10       Maharashtra    3798
# 11            Punjab     495
# 12         Rajasthan     555
# 13         Telangana     312
# 14     Uttar Pradesh    4803
# 15       Uttarakhand     824

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
x = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
df.sort_values(by='Occupation')
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 1689   1003138      Jasper  P00276142      F     36-45   39               1
# 11039  1003792  Geetanjali  P00288642      F     26-35   27               0
# 10838  1005550    Gonzalez  P00194442      F     36-45   42               0
# 8221   1002909       Debra  P00173042      F     26-35   28               1
# 1168   1002645    Caroline  P00207442      F     26-35   26               0
# ...        ...         ...        ...    ...       ...  ...             ...
# 4917   1000368       Olsen  P00293342      M     26-35   35               1
# 4914   1001974         Epp  P00248742      F     36-45   39               1
# 9331   1005474       Mohan  P00111142      F     26-35   30               0
# 1478   1003182  Cartwright  P00074242      F     26-35   28               0
# 1696   1003509   Garverick  P00017042      F     18-25   23               0
#
# ...

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# *Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category*
